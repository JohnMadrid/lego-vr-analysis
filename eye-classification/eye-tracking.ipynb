# %% [markdown]
# # 1. Libraries

# %% [markdown]
# # 2. Data Path and Loading

# %% [markdown]
# # 3. Time Construction

# %% [markdown]
# # 4. Estimate Sampling Rate

# %% [markdown]
# # 5. Filtering Experimental Scope

# %% [markdown]
# # 6. Define Segmentation Units (trial × condition)

# %% [markdown]
# # 7. Define Valid Samples

# %% [markdown]
# # 8. Interpolation

# %% [markdown]
# # 9. Function: Adaptive MAD Threshold (at_mad)

# %% [markdown]
# # 10. Smoothing the Data (5-point Median Filter)

# %% [markdown]
# # 11. Compute Angular Velocity

# %% [markdown]
# # 12. Smooth Angular Velocity (Savitzky–Golay)

# %% [markdown]
# # 13. Compute Adaptive Threshold per Segment

# %% [markdown]
# # 14.Saccade and Fixation Classification

# %% [markdown]
# # 15. Correct Small Events (Minimum Duration Rules)

# %% [markdown]
# # 16. Define Events (Onset, Offset, Duration)

# %% [markdown]
# # 17. Save Outputs
